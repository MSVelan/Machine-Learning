# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("RGB_sample.png")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (600, 900, 3)

# %%
arr[0][0]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
cut = arr[:5,:5]

# %%
plt.imshow(cut)

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=900x600>

# %%
red = arr[:,:,0]

# %%
plt.imshow(red)
