# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("doctor_strange.jpeg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (275, 183, 3)

# %%
arr[0][0]
# Out:
# array([55, 34, 33], dtype=uint8)

# %%
cut = arr[:5,:5]

# %%
plt.imshow(cut)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>

# %%
red = arr[:,:,0]

# %%
plt.imshow(red)

# %%
plt.imshow(arr)

# %%
work = arr.copy()

# %%
work[:,:,[1,2]]=0

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray, cmap="gray")
