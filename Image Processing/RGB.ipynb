# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("RGB_sample.png")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (1080, 1920, 4)

# %%
arr[100][100]
# Out:
# array([  0,   0,   0, 255], dtype=uint8)

# %%
cut = arr[:5,:5]

# %%
plt.imshow(cut)

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
red = arr[:,:,0]
green = arr[:,:,1]
blue = arr[:,:,2]

# %%
plt.imshow(blue)
